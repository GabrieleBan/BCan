# %%
import dataloader
from sklearn.model_selection import train_test_split
from train_pipeline import random_forest

# %%
X,Y = dataloader.get_data_scaled()

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
# Out:
# 0.9999999999999998

# %%
from accuracy_comparison import show_accuracy_metric
model , y_pred =random_forest.train(X_train,y_train)
show_accuracy_metric(model_name=model.__class__.__name__,train=[couple for couple in zip(y_train,y_pred) ])
# Out:
#  train --- RandomForestClassifier : accuracy 1.0

# %%
# test
